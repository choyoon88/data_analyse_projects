# %% [markdown]
# # Life Expectancy and GDP Relationship

# %% [markdown]
# Import related libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the csv file and check the information of the dataframe

# %%
df = pd.read_csv('all_data.csv')
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
df.rename(columns={'Life expectancy at birth (years)': 'Life Expectancy'}, inplace=True)
df.head(17)
# Out:
#    Country  Year  Life Expectancy           GDP
# 0    Chile  2000             77.3  7.786093e+10
# 1    Chile  2001             77.3  7.097992e+10
# 2    Chile  2002             77.8  6.973681e+10
# 3    Chile  2003             77.9  7.564346e+10
# 4    Chile  2004             78.0  9.921039e+10
# 5    Chile  2005             78.4  1.229650e+11
# 6    Chile  2006             78.9  1.547880e+11
# 7    Chile  2007             78.9  1.736060e+11
# 8    Chile  2008             79.6  1.796380e+11
# 9    Chile  2009             79.3  1.723890e+11
# 10   Chile  2010             79.1  2.185380e+11
# 11   Chile  2011             79.8  2.522520e+11
# 12   Chile  2012             79.9  2.671220e+11
# 13   Chile  2013             80.1  2.783840e+11
# 14   Chile  2014             80.3  2.609900e+11
# 15   Chile  2015             80.5  2.425180e+11
# 16   China  2000             71.7  1.211350e+12

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          96 non-null     object
#  1   Year             96 non-null     int64
#  2   Life Expectancy  96 non-null     float64
#  3   GDP              96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# (96, 4)

# %%
df.describe()
# Out:
#               Year  Life Expectancy           GDP
# count    96.000000        96.000000  9.600000e+01
# mean   2007.500000        72.789583  3.880499e+12
# std       4.633971        10.672882  5.197561e+12
# min    2000.000000        44.300000  4.415703e+09
# 25%    2003.750000        74.475000  1.733018e+11
# 50%    2007.500000        76.750000  1.280220e+12
# 75%    2011.250000        78.900000  4.067510e+12
# max    2015.000000        81.000000  1.810000e+13

# %%
df['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015])

# %%
df['Year'].nunique()
# Out:
# 16

# %%
df['Country'].nunique()
# Out:
# 6

# %%
df['Country'].unique()
# Out:
# array(['Chile', 'China', 'Germany', 'Mexico', 'United States of America',
#        'Zimbabwe'], dtype=object)

# %% [markdown]
# DataFrame has data from 6 different countries ('Chile', 'China', 'Germany', 'Mexico', 'United States of America',
#        'Zimbabwe') over the years from 2000 to 2015.

# %% [markdown]
# ## Check Missing Data

# %% [markdown]
# There is no missing data so no further process for data cleaning is needed.

# %%
columns_with_missing_data = df.columns[df.isna().sum() > 0].to_list()
columns_with_missing_data
# Out:
# []

# %% [markdown]
# ## Life Expectancy Over the Years for Each country

# %%
plt.subplots(figsize=(14, 7))
sns.lineplot(x=df['Year'], y=df['Life Expectancy'], hue=df['Country'], marker='o')
ax1.set_title('Life Expectancy Over The Years For Each Country')
plt.show()

# %% [markdown]
# ## GDP Over Years

# %%
plt.subplots(figsize=(14, 7))
sns.lineplot(data=df, x='Year', y='GDP', hue='Country', marker='x')
plt.show()

# %% [markdown]
# # Life Expectancy Over GDP

# %%
plt.subplots(figsize=(14,7))
sns.scatterplot(data=df, y='Life Expectancy', x='GDP', hue='Country')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,7))

ax2 = ax.twinx()

sns.scatterplot(data=df, x='Year', y='Life Expectancy', hue='Country', ax=ax)
sns.scatterplot(data=df, x='Year', y='GDP', style='GDP', hue='Country', legend=False)
sns.move_legend(ax, bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

plt.show()
